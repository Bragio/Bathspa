# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

data = pd.read_csv("/Users/bragi/Downloads/netflix-rotten-tomatoes-metacritic-imdb.csv")
df = pd.DataFrame(data)

ndf = df
ndf["Awards Nominated For"] = ndf["Awards Nominated For"].fillna(0)  # filling in missing values with 0
ndf["Awards Received"] = ndf["Awards Received"].fillna(0)  # filling in missing values with 0
ndf["Boxoffice"] = ndf["Boxoffice"].str.replace("$","").str.replace(",","").astype(float) #removing dollar signs and commas, casting as a float instead of a string

ratings = ndf[["IMDb Score", "Rotten Tomatoes Score", "Metacritic Score"]]
nominated = ndf[ndf['Awards Nominated For'] > 0]
notnominated = ndf[ndf['Awards Nominated For'] == 0]

# %%
sns.heatmap(nominated[["IMDb Score", "Rotten Tomatoes Score", "Metacritic Score"]].corr(), annot=True, cmap="Blues", vmin=0, vmax=1)
# Out:
# <Axes: >

# %%
sns.heatmap(notnominated[["IMDb Score", "Rotten Tomatoes Score", "Metacritic Score"]].corr(), annot=True, cmap="Blues", vmin=0, vmax=1)
# Out:
# <Axes: >

# %%
nominated[["IMDb Score", "Rotten Tomatoes Score", "Metacritic Score"]].agg(["min","max","mean","median","count"])
# Out:
#          IMDb Score  Rotten Tomatoes Score  Metacritic Score
# min        1.000000               0.000000          6.000000
# max        9.500000             100.000000        100.000000
# mean       6.716878              63.048471         58.805405
# median     6.800000              68.000000         60.000000
# count   7643.000000            4807.000000       3700.000000

# %%
notnominated[["IMDb Score", "Rotten Tomatoes Score", "Metacritic Score"]].agg(["min","max","mean","median","count"])
# Out:
#          IMDb Score  Rotten Tomatoes Score  Metacritic Score
# min        1.400000               0.000000          5.000000
# max        9.700000             100.000000         99.000000
# mean       6.201917              48.763175         45.226415
# median     6.300000              46.000000         44.000000
# count   5738.000000            1575.000000        636.000000

# %%
sns.heatmap(knownrev[["Boxoffice", "IMDb Score", "Rotten Tomatoes Score", "Metacritic Score", "Awards Nominated For", "Awards Received"]].corr(), annot=True, cmap="Blues", vmin=0, vmax=1) 
# .corr automatically excludes NaN so we don´t have to worry about that
# Out:
# <Axes: >

# %%
sns.heatmap(knownrev[["IMDb Score", "Rotten Tomatoes Score", "Metacritic Score", "Awards Nominated For", "Awards Received"]].corr(), annot=True, cmap="Blues", vmin=0, vmax=1)
# Out:
# <Axes: >
